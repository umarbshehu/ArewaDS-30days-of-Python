# %% [markdown]
# Exercise: Day 5

# %% [markdown]
# 1

# %%
# Declare an empty list

empty_list = list()

# %% [markdown]
# 2

# %%
# Declare a list with more than 5 items

names = ["juan", "chu", "gabriel", "ken", "mary", "henry"]

# %% [markdown]
# 3

# %%
# Find the length of your list

names = ["juan", "chu", "gabriel", "ken", "mary", "henry"]
print(len(names))
# Out:
# 6

# %% [markdown]
# 4

# %%
# Get the first item, the middle item and the last item of the list

names = ["juan", "chu", "gabriel", "ken", "mary", "henry"]

# first name
first_name = names[0]
print(first_name)

# Middle name
# middle_name =

last_name = names[-1]
print(last_name)
# Out:
# juan
# henry

# %% [markdown]
# 5

# %%
# Declare a list called mixed_data_types, put your(name, age, height, marital status, address)
mixed_data_type = [1, 2, 3, 4, {"age": 23, "height": 6.3, "marital_status": "single", "address": "mecca"}]

# %% [markdown]
# 6

# %%
# Declare a list variable named it_companies and assign initial values Facebook, Google, Microsoft, Apple, IBM, Oracle and Amazon.
it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]

# %% [markdown]
# 7

# %%
# Print the list using print()

games = ["basketball", "soccer", "badmiton", "baseball", "volleyball"]
print(games)
# Out:
# ['basketball', 'soccer', 'badmiton', 'baseball', 'volleyball']

# %% [markdown]
# 8

# %%
# Print the number of companies in the list
it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]
print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %% [markdown]
# 9

# %%
# Print the first, middle and last company
it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]

# first_company
first_company = it_companies[0]
print(first_company)

# middle comapny
# middle_company =

# last comapany
last_company = it_companies[-1]
print(last_company)
# Out:
# Facebook
# Amazon

# %% [markdown]
# 10 & 11

# %%
# Print the first, middle and last company
# Print the list after modifying one of the companies
it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]
it_companies[2] = "Hugginface"

print(it_companies)
# Out:
# ['Facebook', 'Google', 'Hugginface', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %% [markdown]
# 12

# %%
# Add an IT company to it_companies
it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]
it_companies.append("Cisco")
print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Cisco']

# %% [markdown]
# 13

# %%
# Insert an IT company in the middle of the companies list
it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]

len_of_it_company = len(it_companies) # 7
middle = len_of_it_company // 2 # 3(apple)
it_companies[3] = "Huawei"

print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Huawei', 'IBM', 'Oracle', 'Amazon']

# %% [markdown]
# 14

# %%
# Change one of the it_companies names to uppercase (IBM excluded!)
it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]

it_companies[2].upper()
print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %% [markdown]
# 15

# %%
# Join the it_companies with a string '#;'

it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]
it_companies.join("#,")

print(it_companies)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/ubs/Desktop/ArewaDS/ArewaDS-30days-of-Python/Day_5/day_5.ipynb Cell 29 line 4
#       <a href='vscode-notebook-cell:/home/ubs/Desktop/ArewaDS/ArewaDS-30days-of-Python/Day_5/day_5.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> # Join the it_companies with a string '#;'
#       <a href='vscode-notebook-cell:/home/ubs/Desktop/ArewaDS/ArewaDS-30days-of-Python/Day_5/day_5.ipynb#X46sZmlsZQ%3D%3D?line=2'>3</a> it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]
# ----> <a href='vscode-notebook-cell:/home/ubs/Desktop/ArewaDS/ArewaDS-30days-of-Python/Day_5/day_5.ipynb#X46sZmlsZQ%3D%3D?line=3'>4</a> it_companies.join("#,")
#       <a href='vscode-notebook-cell:/home/ubs/Desktop/ArewaDS/ArewaDS-30days-of-Python/Day_5/day_5.ipynb#X46sZmlsZQ%3D%3D?line=5'>6</a> print(it_companies)
#
# AttributeError: 'list' object has no attribute 'join'

# %% [markdown]
# 16

# %%
# Check if a certain company exists in the it_companies list.
it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]

checking_1 = "Microsoft" in it_companies
checking_2 = "Oracle" in it_companies
checking_3 = "Google" in it_companies

print(checking_1)
print(checking_2)
print(checking_3)
# Out:
# True
# True
# True

# %% [markdown]
# 17

# %%
# Sort the list using sort() method

it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]

it_companies.sort()
print(it_companies)
# Out:
# ['Amazon', 'Apple', 'Facebook', 'Google', 'IBM', 'Microsoft', 'Oracle']

# %% [markdown]
# 18

# %%
# Reverse the list in descending order using reverse() method

it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]

it_companies.sort()
print(it_companies)

it_companies.sort(reverse=True)
print(it_companies)
# Out:
# ['Amazon', 'Apple', 'Facebook', 'Google', 'IBM', 'Microsoft', 'Oracle']
# ['Oracle', 'Microsoft', 'IBM', 'Google', 'Facebook', 'Apple', 'Amazon']

# %% [markdown]
# 19

# %%
# Slice out the first 3 companies from the list

it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]

slicing = it_companies[0:3]
print(slicing)
# Out:
# ['Facebook', 'Google', 'Microsoft']

# %% [markdown]
# 20

# %%
# Slice out the last 3 companies from the list

it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]

slicing_2 = it_companies[-3:]
print(slicing_2)
# Out:
# ['IBM', 'Oracle', 'Amazon']

# %% [markdown]
# 21

# %%
# Slice out the middle IT company or companies from the list
it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]

it_companies[3] = "Cisco"
print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Cisco', 'IBM', 'Oracle', 'Amazon']

# %% [markdown]
# 22

# %%
# Remove the first IT company from the list
it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]

it_companies.insert(3, "Cisco")
print(it_companies)

print("---------------------------------")

it_companies.remove("Cisco")
print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Cisco', 'Apple', 'IBM', 'Oracle', 'Amazon']
# ---------------------------------
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %% [markdown]
# 23

# %%
#
