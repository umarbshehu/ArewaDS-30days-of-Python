# %% [markdown]
# # Exercises: Level 1

# %% [markdown]
# # Day 2: 30 Days of Python Programming

# %% [markdown]
# 1.

# %%
first_name = "juan"

# %% [markdown]
# 2.

# %%
last_name = "gracia"

# %% [markdown]
# 3.

# %%
full_name = "mark twin"

# %% [markdown]
# 4

# %%
country = "japan"

# %% [markdown]
# 5

# %%
city = "tokyo"

# %% [markdown]
# 6.

# %%
age = 24

# %% [markdown]
# 7

# %%
year = 2023

# %% [markdown]
# 8

# %%
is_married = True

# %% [markdown]
# 9

# %%
is_true = False

# %% [markdown]
# 10

# %%
is_light_on = False

# %% [markdown]
# 11

# %%
name, age, country, city = "greg", 23, "spain", "madrid"
